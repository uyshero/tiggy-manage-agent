# %% [markdown]
# # 治疗组总生存期比较
#
# Kaplan-Meier 估计、Log-rank 检验和调整后的 Cox 比例风险模型。

# %%
library(survival)
library(ggsurvfit)
source('../R/clean-data.R')

# followup <- clean_followup_data(readxl::read_excel('../data/raw/followup.xlsx'))
# surv_obj <- Surv(followup$followup_month, followup$event)
# km_fit <- survfit(surv_obj ~ treatment, data = followup)
# ggsurvfit(km_fit) + add_risktable()
